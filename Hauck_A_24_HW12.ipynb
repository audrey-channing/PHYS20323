# %% [markdown]
# ## Python Data fitting with various functions - HW 12
# Due Monday Dec 2, 2024
#
#
#
# Dowload the data "miniDR17.fits" from the TCU Online Week 14:<br>
# <i>NOTE: it is a large-ish file and may take a while.</i>
#
# **However, this is a small version of the full science data file (4 GB) which can be found at:**<br>
# https://data.sdss.org/sas/dr17/apogee/spectro/aspcap/dr17/synspec_rev1/allStar-dr17-synspec_rev1.fits
#
#
# My example below will show how to remove Identified bad data,
# however data that are just bad in one quantity may remain
#
# _Use masking to remove any remaining bad values (typically 9999 or -9999 in this file_ , <b>but check!!!! If you are not sure, ask!!!</b>).

# %%
from matplotlib import pyplot as plt
import numpy as np
from astropy.io import fits 
import scipy.optimize as opt

# POTENTIAL FITTING FUNCTIONS
def linear(x,m,b):
    return m*x+b

def poly2(x,a,b,c):
    return a*(x**2)+(b*x)+c

def poly3(x,a,b,c,d):
    return (a*(x**3))+(b*(x**2))+(c*x)+d

def cosfit (x,a,b,c,d):
    return a*np.cos(b*x + c) + d

def exponential(x,a,b,c,d):
    return a*np.exp(b*x + c) + d


# Monte Carlo-version of 2 parameter Curve Fit that can use BOTH x and Y errors
def mcFit2(func, x, y, x_err=0.1, y_err=0.1, p0=[0,0]):
    slope = list()
    y_ints = list()
    iters = 500 
    for i in range(iters):
        # remember random normal distribution (Gaussian)
        weightsx = np.random.randn(len(y))
        weightsy = np.random.randn(len(y))
        y_adj = y + y_err*weightsy
        x_adj = x + x_err*weightsx 
        popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
        slope.append(popt[0])
        y_ints.append(popt[1])
    return (np.median(slope),np.median(y_ints))


# Monte Carlo-version of 3 parameter Curve Fit that can use BOTH x and Y errors
def mcFit3(func, x, y, x_err=0.1, y_err=0.1,p0=[1,1,1]):
    paramA = list()
    paramB = list()
    paramC = list()
    iters = 500 
    for i in range(iters):
        # remember random normal distribution (Gaussian)
        weightsx = np.random.randn(len(y))
        weightsy = np.random.randn(len(y))
        y_adj = y + y_err*weightsy
        x_adj = x + x_err*weightsx 
        popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
        paramA.append(popt[0])
        paramB.append(popt[1])
        paramC.append(popt[2])
    return (np.median(paramA),np.median(paramB),np.median(paramC))

# Monte Carlo-version of 4 parameter Curve Fit that can use BOTH x and Y errors
def mcFit4(func, x, y, x_err=0.1, y_err=0.1, p0=[1,1,1,1]):
    paramA = list()
    paramB = list()
    paramC = list()
    paramD = list()
    iters = 500 
    for i in range(iters):
        # remember random normal distribution (Gaussian)
        weightsx = np.random.randn(len(y))
        weightsy = np.random.randn(len(y))
        y_adj = y + y_err*weightsy
        x_adj = x + x_err*weightsx 
        popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
        paramA.append(popt[0])
        paramB.append(popt[1])
        paramC.append(popt[2])
        paramD.append(popt[3])
    return (np.median(paramA),np.median(paramB),np.median(paramC),np.median(paramD))

# %%
# READ IN FITS FILES
star_hdus = fits.open('miniDR17.fits')
star = star_hdus[1].data
print(star_hdus[1].columns)
star_hdus.close()
# Out:
# ColDefs(
#     name = 'APOGEE_ID'; format = '30A'
#     name = 'RA'; format = 'D'
#     name = 'DEC'; format = 'D'
#     name = 'GLON'; format = 'D'
#     name = 'GLAT'; format = 'D'
#     name = 'TEFF'; format = 'E'
#     name = 'TEFF_ERR'; format = 'E'
#     name = 'LOGG'; format = 'E'
#     name = 'LOGG_ERR'; format = 'E'
#     name = 'J'; format = 'E'
#     name = 'J_ERR'; format = 'E'
#     name = 'K'; format = 'E'
#     name = 'K_ERR'; format = 'E'
#     name = 'SNR'; format = 'E'
#     name = 'VHELIO_AVG'; format = 'E'
#     name = 'VERR'; format = 'E'
#     name = 'FE_H'; format = 'E'
#     name = 'FE_H_ERR'; format = 'E'
#     name = 'O_FE'; format = 'E'
#     name = 'O_FE_ERR'; format = 'E'
#     name = 'NI_FE'; format = 'E'
#     name = 'NI_FE_ERR'; format = 'E'
#     name = 'NVISITS'; format = 'J'
#     name = 'VSCATTER'; format = 'E'
#     name = 'ASPCAPFLAG'; format = 'K'
#     name = 'STARFLAG'; format = 'K'
#     name = 'EXTRATARG'; format = 'J'
#     name = 'GAIA_PARALLAX'; format = 'E'
#     name = 'GAIA_PARALLAX_ERROR'; format = 'E'
#     name = 'GAIA_PMRA'; format = 'E'
#     name = 'GAIA_PMRA_ERROR'; format = 'E'
#     name = 'GAIA_PMDEC'; format = 'E'
#     name = 'GAIA_PMDEC_ERROR'; format = 'E'
#     name = 'GAIA_PHOT_G_MEAN_MAG'; format = 'E'
#     name = 'GAIA_PHOT_BP_MEAN_MAG'; format = 'E'
#     name = 'GAIA_PHOT_RP_MEAN_MAG'; format = 'E'
# )

# %%
# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolean Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) 
bd = (np.bitwise_and(star['aspcapflag'], badbits) != 0) |\
     (np.bitwise_and(star['starflag'], suspectbits) != 0) 

good = np.where(gd)[0]
bad = np.where(bd)[0]

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.scatter(star['RA'][good],star['DEC'][good],s=1,c='b',alpha=0.1)
ax.scatter(star['RA'][bad],star['DEC'][bad],s=1,c='r',alpha=0.1)


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.show()

# %%
# EXAMPLE FIT - DR. FRINCHABOY
# --------------------------------------------
# First use Linear, Polnomial, and Cosine Fits
# Select stars only with with  −2 < GLAT < 2   
# 
# I FIT RA & DEC data versus LINEAR, POLY2, AND COSFIT in this example.  
#
# TWO BITWISE FLAGS TO REMOVE FOR OBVIOUSLY BAD DATA             
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

#=================================================================================
# Make a Boolena Mask to remove bad data - AND ANY OTHER NEEDED CUTS 
# (e.g., −2 < GLAT < 2 ) or other 'bad' data not removed by the flags.
ct1 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
     (star['GLAT'] < 2) &\
     (star['GLAT'] > -2) 
cut1 = np.where(ct1)[0]

#=================================================================================
## LINEAR FIT (2 parameter)
# slope, intercept = mcFit2(linear, star['RA'][cut1], star['DEC'][cut1], 0.001, \
#                           0.001, p0=[0,0])
# print(f'LINEAR: {slope:.3f}, {intercept:.3f}')

# #=================================================================================
# ## POLY2 FIT (3 parameter)
# polyA, polyB, polyC,  = mcFit3(poly2, star['RA'][cut1], star['DEC'][cut1], 0.001, \
#                          0.001,p0=[600,1,1])
# print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')

# #=================================================================================
# ## COS FIT (4 parameter)
# cfA, cfB, cfC, cfD = mcFit4(cosfit, star['RA'][cut1], star['DEC'][cut1], 0.001, \
#                             0.001,p0=[60,0.02,0,0])
# print(f'COSFIT: {cfA:.3f}, {cfB:.3f}, {cfC:.3f}, {cfD:.3f}')
#=================================================================================



# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# PLOT DATA AND ERROR BARS
ax1.scatter(star['RA'][cut1],star['DEC'][cut1],s=1,c='b',alpha=0.1)
ax1.errorbar((star['RA'][cut1]),star['DEC'][cut1], xerr=(0.001),
             yerr=(0.001), ecolor='grey',fmt='none', capsize=5, zorder=0)


#=================================================================================
# PLOT DATA FITS FROM ABOVE
x_plot = np.linspace(0,360,1000) # X-PLOTING FOR FITS

#=================================================================================
#linear fit
ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#poly2 fit
ax1.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
#cosfit
ax1.plot(x_plot,cosfit(x_plot, cfA, cfB, cfC, cfD), label='Fit: cosfit')

plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 60
#      56 x_plot = np.linspace(0,360,1000) # X-PLOTING FOR FITS
#      58 #=================================================================================
#      59 #linear fit
# ---> 60 ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#      61 #poly2 fit
#      62 ax1.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
#
# NameError: name 'slope' is not defined

# %% [markdown]
# # Homework #12
#
# **REMINDER:** *All coding assignment will be turned in as .ipynb files, to the same PHYS_X0223 repository on GitHub.*
# *They should be turned in with the following naming:*
#
#     Lastname_Firstinitial_24_HW12a.ipynb

# %% [markdown]
# ## DATA FIT 1
#
# Fit a linear, polynomial (poly2), and a polynomial (poly3) functions and to the following selections of the data:
# 1. Select stars only with with $ GLAT > 20$ <br>
#    __Fit Fe\_H,  (Fe\_H\_ERR)  vs.  O\_FE (O\_FE\_ERR)__<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# TWO BITWISE FLAGS TO REMOVE FOR OBVIOUSLY BAD DATA             
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

#=================================================================================
##Editted code
ct2 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
      (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
      (star['GLAT'] > 20) & \
      (np.invert(np.isnan(star['FE_H']))) & \
      (np.invert(np.isnan(star['O_FE'])))
cut2 = np.where(ct2)[0] 

#=================================================================================
## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['Fe_H'][cut2], star['O_FE'][cut2], 0.001, \
                          0.001, p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')

#=================================================================================
## POLY2 FIT (3 parameter)
polyA, polyB, polyC,  = mcFit3(poly2, star['Fe_H'][cut2], star['O_FE'][cut2], 0.001, \
                         0.001,p0=[20,1,1]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')

#=================================================================================
## POLY3 FIT (4 parameter)
polyA, polyB, polyC, polyD  = mcFit4(poly3, star['Fe_H'][cut2], star['O_FE'][cut2], 0.001, \
                         0.001,p0=[10,1,1,1]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
#=================================================================================

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# PLOT DATA AND ERROR BARS
ax1.scatter(star['Fe_H'][cut2],star['O_FE'][cut2],s=1,c='b',alpha=0.1)
#ax1.errorbar((star['Fe_H'][cut2]),star['O_FE'][cut2], xerr=(0.001),
             #yerr=(0.001), ecolor='grey',fmt='none', capsize=5, zorder=0)


#=================================================================================
# PLOT DATA FITS FROM ABOVE
x_plot = np.linspace(-2,2,1000) # X-PLOTING FOR FITS

#=================================================================================
#linear fit
ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#poly2 fit
ax1.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
#poly3 fit
ax1.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')

plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: -0.233, 0.054
# POLY2: -0.074, -0.317, 0.048
# POLY2: 0.075, 0.093, -0.262, 0.045

# %% [markdown]
# 1. What are the best-fit values of the parameters?
# Best fit parameters seem to be associated with the poly3 line of best fit if, where a,b,c,d associate to 10,1,1,1
#
# 2. Which fucntion fits the data best?
# None of the functions fit the data perfectly, since the data takes on more of a blob shape, but if I were to choose any of them I would
# probably say poly3 follows the center of the data the best.
#
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)
# No.

# %% [markdown]
# ## DATA FIT 2
#
# Fit a linear, polynomial (poly2), and a polynomial (poly3) functions and to the following selections of the data:
#
# 2. Select stars only with with $-1< GLAT < 1$ <br>
#    __Fit Fe\_H,  (Fe\_H\_ERR)  vs.  O\_FE (O\_FE\_ERR)__<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code, from part 1, and plot the results here
# TWO BITWISE FLAGS TO REMOVE FOR OBVIOUSLY BAD DATA             
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

#=================================================================================
##Editted code
ct3 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
      (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
      (star['GLAT'] < 1) &\
      (star['GLAT'] > -1) &\
      (np.invert(np.isnan(star['FE_H']))) & \
      (np.invert(np.isnan(star['O_FE'])))
cut3 = np.where(ct3)[0] 

#=================================================================================
## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['Fe_H'][cut3], star['O_FE'][cut3], 0.001, \
                          0.001, p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')

#=================================================================================
## POLY2 FIT (3 parameter)
polyA, polyB, polyC,  = mcFit3(poly2, star['Fe_H'][cut3], star['O_FE'][cut3], 0.001, \
                         0.001,p0=[10,1,1]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')

#=================================================================================
## POLY3 FIT (4 parameter)
polyA, polyB, polyC, polyD  = mcFit4(poly3, star['Fe_H'][cut3], star['O_FE'][cut3], 0.001, \
                         0.001,p0=[10,1,1,1]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
#=================================================================================

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# PLOT DATA AND ERROR BARS
ax1.scatter(star['Fe_H'][cut3],star['O_FE'][cut3],s=1,c='b',alpha=0.1)
#ax1.errorbar((star['Fe_H'][cut3]),star['O_FE'][cut3], xerr=(0.001),
             #yerr=(0.001), ecolor='grey',fmt='none', capsize=5, zorder=0)


#=================================================================================
# PLOT DATA FITS FROM ABOVE
x_plot = np.linspace(-1.5,1,1000) # X-PLOTING FOR FITS
#=================================================================================
#linear fit
ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#poly2 fit
ax1.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
#poly3 fit
ax1.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')

plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: -0.137, 0.040
# POLY2: -0.020, -0.146, 0.041
# POLY2: 0.091, 0.131, -0.131, 0.033

# %% [markdown]
# 1. What are the best-fit values of the parameters?
# The best fit values were determined to be associated with the poly3 fit being where the a,b,c,d correlated to 10,1,1,1
#
# 2. Which fucntion fits the data best?
# The poly3 function appears to fit the data the best, following the overall curve of the bulk of the data
#
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)
# There does seem to be a second population above the main 'blob'. The outlier data doesn't seem to follow a linear patter but rather a curve
# that possibly a cos function with a large amplitude could acount for.

# %% [markdown]
# ## DATA FIT 3
#
# Fit a linear, polynomial (poly3), and a exponetial functions and to the following selections of the data:
# 3. Select stars only with with $340 < GLON < 360$ <br>
#    __Fit TEFF,  (TEFF\_ERR)  vs.  LOGG (LOGG\_ERR)__<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code and plot the results here
# write your fitting code, from part 1, and plot the results here
# TWO BITWISE FLAGS TO REMOVE FOR OBVIOUSLY BAD DATA             
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

#=================================================================================
##Editted code
ct4 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
      (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
      (star['GLON'] < 360) &\
      (star['GLON'] > 340) &\
      (np.invert(np.isnan(star['TEFF']))) & \
      (np.invert(np.isnan(star['LOGG'])))
cut4 = np.where(ct4)[0] 

#=================================================================================
## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['TEFF'][cut4], star['LOGG'][cut4], 0.001, \
                          0.001, p0=[-0.0001, 4])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')

#=================================================================================
## POLY3 FIT (4 parameter)
polyA, polyB, polyC, polyD  = mcFit4(poly3, star['TEFF'][cut4], star['LOGG'][cut4], 0.001, \
                         0.001,p0=[10,1,1,1]) #change p0
print(f'POLY3: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')

#=================================================================================
x_scaled = star['TEFF'][cut4] / 10000  # Scale TEFF to a range between 0.25 and 2
x_plot_scaled = x_plot / 10000         # Scale the x_plot similarly
## EXPONENTIAL FIT (4 parameter)
exA, exB, exC, exD = mcFit4(exponential, star['TEFF'][cut4], star['LOGG'][cut4], 0.001, \
                            0.001,p0 = [-1.8, -0.001, 5, 3.8])
 
print(f'EXPONENTIAL: {exA:.3f}, {exB:.3f}, {exC:.3f}, {exD:.3f}')
#=================================================================================

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# PLOT DATA 
ax1.scatter(star['TEFF'][cut4],star['LOGG'][cut4],s=1,c='b',alpha=0.3)

#=================================================================================
# PLOT DATA FITS FROM ABOVE
x_plot = np.linspace(2500,20000,1000) # X-PLOTING FOR FITS

#=================================================================================
#linear fit
ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#poly3 fit
ax1.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')
#exponentialfit
ax1.plot(x_plot,exponential(x_plot, exA, exB, exC, exD), label='Fit: exponential')

plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: 0.000, 0.347
# POLY3: 0.000, -0.000, 0.002, -4.057
# /var/folders/7v/9jt0h_7j1cb0r_zr90jxxqlw0000gn/T/ipykernel_42514/3954844722.py:71: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
# EXPONENTIAL: -0.193, -0.000, 4.045, 4.732

# %% [markdown]
# 1. What are the best-fit values of the parameters?
# The best fit values were -1.8, -0.001, 4.1, 3.8 for the exponential line of best fit.
#
# 3. Which fucntion fits the data best?
# The exponetial function appears to fit the data the best, following the overall curve of the bulk of the data, and platauing at 4, but it
# doesn't account for the other chunk of data found below that line.
#
# 4. Is there a second population? (Can you fit outliers with a reasonable linear trend?)
# There does seem to be second population above the main exponetial fit,  it could be met with a linear fit where y=4 or slightly above 4 .

# %% [markdown]
# ## DATA FIT 4
#
# Fit  a linear, a exponential, and a polynomial (poly2) functions and to the following selections of the data:
# 4. Select stars only with with $DEC < -50$ and $50 < RA < 120$ <br>
#    __Fit TEFF,  (TEFF\_ERR)   vs.  (star['J'] - star['K']) (JK_ERR)__<br>
# <br>
# <b>NOTE: you will have to create a (J-K) error:</b>  JK_ERR = np.sqrt( J\_ERR^2 + K\_ERR^2 )<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code and plot the results here
# write your fitting code and plot the results here
# write your fitting code, from part 1, and plot the results here
# TWO BITWISE FLAGS TO REMOVE FOR OBVIOUSLY BAD DATA             
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

#=================================================================================
##Editted code
ct5 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
      (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
      (star['DEC'] < -50) &\
      (star['RA'] > 50) &\
      (star['RA'] < 120) &\
      (np.invert(np.isnan(star['TEFF']))) & \
      (np.invert(np.isnan(star['J']-star['K'])))
cut5 = np.where(ct5)[0] 

#=================================================================================
## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['TEFF'][cut5], (star['J']-star['K'])[cut5], 0.001, \
                          0.001, p0=[-0.0001, 4])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')

#=================================================================================
## POLY2 FIT (3 parameter)
polyA, polyB, polyC,  = mcFit3(poly2, star['TEFF'][cut5], (star['J']-star['K'])[cut5], 0.001, \
                         0.001,p0=[1e-5, -0.01, 4.5,]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')

#=================================================================================
x_scaled = star['TEFF'][cut5] / 10000  # Scale TEFF to a range between 0.25 and 2
x_plot_scaled = x_plot / 10000         # Scale the x_plot similarly
## EXPONENTIAL FIT (4 parameter)
exA, exB, exC, exD = mcFit4(exponential, star['TEFF'][cut5], (star['J']-star['K'])[cut5], 0.001, \
                            0.001,p0 = [-1.7, -0.001, 4.2, 1])
 
print(f'EXPONENTIAL: {exA:.3f}, {exB:.3f}, {exC:.3f}, {exD:.3f}')
#=================================================================================

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# PLOT DATA 
ax1.scatter(star['TEFF'][cut5],(star['J']-star['K'])[cut5],s=1,c='b',alpha=0.3)

#=================================================================================
# PLOT DATA FITS FROM ABOVE
x_plot = np.linspace(2500,20000,1000) # X-PLOTING FOR FITS

#=================================================================================
#linear fit
ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#poly2 fit
ax1.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
#exponentialfit
ax1.plot(x_plot,exponential(x_plot, exA, exB, exC, exD), label='Fit: exponential')

plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: -0.000, 1.925
# POLY2: 0.000, -0.001, 3.084
# /var/folders/7v/9jt0h_7j1cb0r_zr90jxxqlw0000gn/T/ipykernel_42514/3954844722.py:71: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
# EXPONENTIAL: 0.453, -0.000, 2.530, -0.087

# %% [markdown]
# 1. What are the best-fit values of the parameters?
# The best fit values were -1.7, -0.001, 4.2, 1 correlating to variables a,b,c,d for the exponential line of best fit.
#
# 2. Which fucntion fits the data best?
# The exponetial function appears to fit the data the best, following the overall declining curve of the bulk of the data, and platauing at 0, but itdoesn't account for the other chunk of data found above that line or at the very beining of the graph. An expontential fucntion with a rapid decline would fit best but I wasn't able to find values to create that curve.
#
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)
# While the poly curve acount for some outliers there aren't enough outliers to begin with to conclude there is indeed a second population.

# %% [markdown]
# ## DATA FIT 5
#
# Fit  a linear, a polynomial (poly3), and a cosfit functions and to the following selections of the data:
# 5. Select stars only with with $-10< GLAT < 10$<br>
#    __Fit GLON (0.0001) vs.  VHEILO\_AVG (VERR)__<br>
# <br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code and plot the results here
# write your fitting code and plot the results here
# write your fitting code, from part 1, and plot the results here
# TWO BITWISE FLAGS TO REMOVE FOR OBVIOUSLY BAD DATA             
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

#=================================================================================
##Editted code
ct6 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
      (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
      (star['GLAT'] < 10) &\
      (star['GLAT'] > -10) &\
      (np.invert(np.isnan(star['GLON']))) & \
      (np.invert(np.isnan(star['VHEILO_AVG'])))
cut6 = np.where(ct3)[0] 

#=================================================================================
## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['GLON'][cut6], star['VHEILO_AVG'][cut6], 0.001, \
                          0.001, p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')

#=================================================================================
## POLY3 FIT (4 parameter)
polyA, polyB, polyC, polyD  = mcFit3(poly3, star['GLON'][cut6], star['VHEILO_AVG'][cut6], 0.001, \
                         0.001,p0=[10,1,1,1]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f},{polyD:.3f}')

#=================================================================================
## COS FIT (4 parameter)
cfA, cfB, cfC, cfD = mcFit4(cosfit, star['GLON'][cut6], star['VHEILO_AVG'][cut6], 0.001, \
                            0.001,p0=[1,0.02,0,0]) 
print(f'COSFIT: {cfA:.3f}, {cfB:.3f}, {cfC:.3f}, {cfD:.3f}')
#=================================================================================

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# PLOT DATA AND ERROR BARS
ax1.scatter(star['GLON'][cut6],star['VHEILO_AVG'][cut6],s=1,c='b',alpha=0.1)
#ax1.errorbar((star['Fe_H'][cut3]),star['O_FE'][cut3], xerr=(0.001),
             #yerr=(0.001), ecolor='grey',fmt='none', capsize=5, zorder=0)


#=================================================================================
# PLOT DATA FITS FROM ABOVE
x_plot = np.linspace(-1.5,1,1000) # X-PLOTING FOR FITS
#=================================================================================
#linear fit
ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#poly3 fit
ax1.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')
#cosfit
ax1.plot(x_plot,cosfit(x_plot, cfA, cfB, cfC, cfD), label='Fit: cosfit')

plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.12/site-packages/astropy/io/fits/column.py:2145, in _get_index(names, key)
#    2144 try:
# -> 2145     indx = names.index(key.rstrip())
#    2146 except ValueError:
#    2147     # try to match case-insentively,
#
# ValueError: 'VHEILO_AVG' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[128], line 15
#       6 suspectbits = 2**16    # star flag - Stellar parameters
#       8 #=================================================================================
#       9 ##Editted code
#      10 ct6 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
#      11       (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
#      12       (star['GLAT'] < 10) &\
#      13       (star['GLAT'] > -10) &\
#      14       (np.invert(np.isnan(star['GLON']))) & \
# ---> 15       (np.invert(np.isnan(star['VHEILO_AVG'])))
#      16 cut6 = np.where(ct3)[0]
#      18 #=================================================================================
#      19 ## LINEAR FIT (2 parameter)
#
# File /opt/miniconda3/lib/python3.12/site-packages/astropy/io/fits/fitsrec.py:508, in FITS_rec.__getitem__(self, key)
#     505     return super().__getitem__(key)
#     507 if isinstance(key, str):
# --> 508     return self.field(key)
#     510 # Have to view as a recarray then back as a FITS_rec, otherwise the
#     511 # circular reference fix/hack in FITS_rec.field() won't preserve
#     512 # the slice.
#     513 out = self.view(np.recarray)[key]
#
# File /opt/miniconda3/lib/python3.12/site-packages/astropy/io/fits/fitsrec.py:690, in FITS_rec.field(self, key)
#     685 """
#     686 A view of a `Column`'s data as an array.
#     687 """
#     688 # NOTE: The *column* index may not be the same as the field index in
#     689 # the recarray, if the column is a phantom column
# --> 690 column = self.columns[key]
#     691 name = column.name
#     692 format = column.format
#
# File /opt/miniconda3/lib/python3.12/site-packages/astropy/io/fits/column.py:1754, in ColDefs.__getitem__(self, key)
#    1752 def __getitem__(self, key):
#    1753     if isinstance(key, str):
# -> 1754         key = _get_index(self.names, key)
#    1756     x = self.columns[key]
#    1757     if _is_int(key):
#
# File /opt/miniconda3/lib/python3.12/site-packages/astropy/io/fits/column.py:2154, in _get_index(names, key)
#    2152     indx = names.index(_key)
#    2153 elif count == 0:
# -> 2154     raise KeyError(f"Key '{key}' does not exist.")
#    2155 else:  # multiple match
#    2156     raise KeyError(f"Ambiguous key name '{key}'.")
#
# KeyError: "Key 'VHEILO_AVG' does not exist."

# %% [markdown]
# ## DATA FIT 6
#
# Fit  a linear and a polynomial (poly2 AND poly3) functions and to the following selections of the data:
# 7. __Fit Fe\_H,  (Fe\_H\_ERR)  vs.  NI\_FE (NI\_FE\_ERR)__<br>
# <br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code and plot the results here
# TWO BITWISE FLAGS TO REMOVE FOR OBVIOUSLY BAD DATA             
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

#=================================================================================
##Editted code
ct7 = (np.bitwise_and(star['aspcapflag'], badbits) == 0) & \
      (np.bitwise_and(star['starflag'], suspectbits) == 0) & \
      (star['GLAT'] > 20) & \
      (np.invert(np.isnan(star['FE_H']))) & \
      (np.invert(np.isnan(star['NI_FE'])))
cut7 = np.where(ct2)[0] 

#=================================================================================
## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['Fe_H'][cut7], star['NI_FE'][cut7], 0.001, \
                          0.001, p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')

#=================================================================================
## POLY2 FIT (3 parameter)
polyA, polyB, polyC,  = mcFit3(poly2, star['Fe_H'][cut7], star['NI_FE'][cut7], 0.001, \
                         0.001,p0=[20,1,1]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')

#=================================================================================
## POLY3 FIT (4 parameter)
polyA, polyB, polyC, polyD  = mcFit4(poly3, star['Fe_H'][cut7], star['NI_FE'][cut7], 0.001, \
                         0.001,p0=[10,1,1,1]) #change p0
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
#=================================================================================

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# PLOT DATA AND ERROR BARS
ax1.scatter(star['Fe_H'][cut7],star['NI_FE'][cut7],s=1,c='b',alpha=0.1)
#ax1.errorbar((star['Fe_H'][cut2]),star['O_FE'][cut2], xerr=(0.001),
             #yerr=(0.001), ecolor='grey',fmt='none', capsize=5, zorder=0)


#=================================================================================
# PLOT DATA FITS FROM ABOVE
x_plot = np.linspace(-2,2,1000) # X-PLOTING FOR FITS

#=================================================================================
#linear fit
ax1.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
#poly2 fit
ax1.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
#poly3 fit
ax1.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')

plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: 0.021, 0.019
# POLY2: -0.000, 0.021, 0.019
# POLY2: -0.026, -0.055, 0.003, 0.020

# %% [markdown]
# 1. What are the best-fit values of the parameters?
# The best fit values were 0,0 correlating to variables a,b, for the linear line of best fit.
#
# 2. Which fucntion fits the data best?
# The linear function appears to fit the data the best, following the trend of the data points, but it looks more like a blob then following any distinct curve.
#
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)
# No.
